# %% [markdown]
# # Balance Data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 1000

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance
np.random.seed(2020)

import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

X1 = df.drop(['y'], axis=1)

y = df.y

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
    
clf.fit(x_train, y_train)

# db on train data
x1 = x_train['x1']
x2 = x_train['x2']

x_min, x_max = X1['x1'].min() - 1, X1['x1'].max() + 1
y_min, y_max = X1['x2'].min() - 1, X1['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_train,
                              s=20, edgecolor='k')
plt.title('Original Train Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_train,
                              s=20, edgecolor='k')
plt.title('Original Train Data')

plt.show()

# db on test data
x1 = x_test['x1']
x2 = x_test['x2']

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()


print('Training Accuracy:', clf.score(x_train, y_train))

# Prediction and accuracy on testing data
y_pred = clf.predict(x_test)
print('Testing Accuracy:', metrics.accuracy_score(y_pred, y_test))

y_pred = clf.predict(x_train)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_train, y_pred).ravel()
    
d1 = pd.DataFrame({'Data':'Train',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

y_pred = clf.predict(x_test)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_test, y_pred).ravel()
    
d2 = pd.DataFrame({'Data':'Test',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)], 
                     'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

d = pd.concat([d1, d2], ignore_index=True)

d
# Out:
# Training Accuracy: 0.9123809523809524
# Testing Accuracy: 0.9133333333333333
#     Data  Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0  Train            0.840170            0.949031  0.912381            0.894600
# 1   Test            0.846416            0.945634  0.913333            0.896025

# %% [markdown]
# # Imbalanced Data

# %%
p = .02
df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
    
from sklearn.linear_model import LogisticRegression


clf.fit(x_train, y_train)

# db on train data
x1 = x_train['x1']
x2 = x_train['x2']

x_min, x_max = X1['x1'].min() - 1, X1['x1'].max() + 1
y_min, y_max = X1['x2'].min() - 1, X1['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_train,
                              s=20, edgecolor='k')
plt.title('Original Train Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_train,
                              s=20, edgecolor='k')
plt.title('Original Train Data')

plt.show()

# db on test data
x1 = x_test['x1']
x2 = x_test['x2']

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()


plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()


print('Training Accuracy:', clf.score(x_train, y_train))

# Prediction and accuracy on testing data
y_pred = clf.predict(x_test)
print('Testing Accuracy:', metrics.accuracy_score(y_pred, y_test))

y_pred = clf.predict(x_train)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_train, y_pred).ravel()
    
d1 = pd.DataFrame({'Data':'Train',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

y_pred = clf.predict(x_test)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_test, y_pred).ravel()
    
d2 = pd.DataFrame({'Data':'Test',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)], 
                     'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

d = pd.concat([d1, d2], ignore_index=True)

d
# Out:
# Training Accuracy: 0.995049504950495
# Testing Accuracy: 0.9917491749174917
#     Data  Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0  Train            0.500000                 1.0  0.995050            0.750000
# 1   Test            0.166667                 1.0  0.991749            0.583333

# %% [markdown]
# # Resampled Data

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
x_res, y_res = ros.fit_resample(x_train, y_train)

df_train = pd.concat([x_train, y_train], axis=1)
df_test = pd.concat([x_test, y_test], axis=1)

df_res = pd.concat([x_res, y_res], axis=1)

# db on test data
x1 = x_res['x1']
x2 = x_res['x2']

clf.fit(x_res, y_res)

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_res,
                              s=20, edgecolor='k')
plt.title('Resampled Train Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_res,
                              s=20, edgecolor='k')
plt.title('Resampled Train Data')

plt.show()


# db on test data
x1 = x_test['x1']
x2 = x_test['x2']

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_test,
                              s=20, edgecolor='k')
plt.title('Original Test Data')

plt.show()

# Prediction and accuracy on testing data
y_pred = clf.predict(x_test)
print('Testing Accuracy:', metrics.accuracy_score(y_pred, y_test))

y_pred = clf.predict(x_train)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_train, y_pred).ravel()
    
d1 = pd.DataFrame({'Data':'Train',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

y_pred = clf.predict(x_test)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_test, y_pred).ravel()
    
d2 = pd.DataFrame({'Data':'Test',
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)], 
                     'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

d = pd.concat([d1, d2], ignore_index=True)

d
# Out:
# Testing Accuracy: 0.9372937293729373
#     Data  Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0  Train            1.000000            0.936429  0.937058            0.968214
# 1   Test            0.833333            0.938333  0.937294            0.885833

# %% [markdown]
# # Second Time

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from scipy.stats import multivariate_normal

n = 1000
np.random.seed(2020)

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n, ).T


df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

X1 = df.drop(['y'], axis=1)

y = df.y

clf.fit(X, y)

# db on train data
x1 = X['x1']
x2 = X['x2']

x_min, x_max = X1['x1'].min() - 1, X1['x1'].max() + 1
y_min, y_max = X1['x2'].min() - 1, X1['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y,
                              s=20, edgecolor='k')
plt.title('Original Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y,
                              s=20, edgecolor='k')
plt.title('Original Data')

plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Minority Accuracy ':[tp/(tp+fn)],
                     'Majority Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

def ir_db(p=0.2, df = df):
    
    df = df.drop(df.index[0:int((1-p)*n)], axis=0)

    X = df.drop(['y'], axis=1)
    y = df.y

    clf.fit(X, y)

    # db on train data
    x1 = X['x1']
    x2 = X['x2']

    x_min, x_max = X1['x1'].min() - 1, X1['x1'].max() + 1
    y_min, y_max = X1['x2'].min() - 1, X1['x2'].max() + 1

    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.scatter(x1, x2, c=y,
                                  s=20, edgecolor='k')
    plt.title('Original Data')
    
    #plt.savefig('filename.png', dpi=300)
    plt.show()

    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(x1, x2, c=y,
                                  s=20, edgecolor='k')
    plt.title('Original Data')

    plt.show()

    y_pred = clf.predict(X)
    [tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()

    d = pd.DataFrame({
                        'Minority Accuracy ':[tp/(tp+fn)],
                         'Majority Accuracy ':[tn/(tn+fp)],
                          'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                      'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  

    print(d)

d
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0               0.845               0.945  0.911667               0.895

# %%
ir_db(.4)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0                0.72               0.982  0.938333               0.851

# %%
ir_db(.3)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0            0.656667               0.989  0.945652            0.822833

# %%
ir_db(.2)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0               0.575               0.993     0.955               0.784

# %%
ir_db(.1)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0                0.53               0.994  0.971905               0.762

# %%
ir_db(.05)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0                0.42               0.997  0.982927              0.7085

# %%
ir_db(.03)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0            0.266667               0.999  0.988177            0.632833

# %%
ir_db(.01)
# Out:
#    Minority Accuracy   Majority Accuracy   Accuracy  Balanced Accuracy
# 0                 0.1                 1.0  0.995522                0.55

# %% [markdown]
# # Other resampling methods

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 1000

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(2020)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


p = .02
df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Original Data')

plt.show()

from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

plt.scatter(X_res['x1'], X_res['x2'], c=y_res,
                              s=20, edgecolor='k')
plt.title('Under-sampled Data')

plt.show()

# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


p = 1
df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Is A Yellow?')

plt.savefig('a_col.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
d
# Out:
#    Yellow Accuracy   Purple Accuracy   Accuracy  Balanced Accuracy
# 0               0.9               0.9       0.9                 0.9

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


p = 1
df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Is A Red?')

plt.savefig('a_col.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()


d = pd.DataFrame({'Purple Accuracy ':[tp/(tp+fn)],
                     'Yellow Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
d
# Out:
#    Purple Accuracy   Yellow Accuracy   Accuracy  Balanced Accuracy
# 0               0.9               0.9       0.9                 0.9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def render_mpl_table(data, col_width=10.0, row_height=0.625, font_size=10,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')
    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)
    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in mpl_table._cells.items():
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax.get_figure(), ax

fig,ax = render_mpl_table(d, header_columns=0, col_width=2.0)
fig.savefig("accuracy.png")

# %% [markdown]
# # p = 0.3

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


p = .3
df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Unbalanced Data')

plt.savefig('unbal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db2.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
d
# Out:
#    Yellow Accuracy   Purple Accuracy   Accuracy  Balanced Accuracy
# 0          0.666667               1.0  0.956522            0.833333

# %%
p = 1

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_04.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
# print(d.to_markdown())

# %% [markdown]
# # p=0.4

# %%
p = .4

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_04.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |               0.75 |                  1 |   0.958333 |                0.875 |

# %% [markdown]
# # p = 0.3

# %%
p = .3

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y


df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_03.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |           0.666667 |                  1 |   0.956522 |             0.833333 |

# %% [markdown]
# # p = .2

# %%
p = .2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y



df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_02.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                0.5 |                  1 |   0.954545 |                 0.75 |

# %% [markdown]
# # p = .1

# %%
p = .1
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y



df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_01.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                  0 |                  1 |   0.952381 |                  0.5 |

# %% [markdown]
# # Oversampling

# %%
p = .1
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y



df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_02.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())


from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
x_res, y_res = ros.fit_resample(X, y)


# db on test data
x1 = x_res['x1']
x2 = x_res['x2']

clf.fit(x_res, y_res)

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_res, s=20, edgecolor='k')
plt.title('Oversampled Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_res,
                              s=20, edgecolor='k')
plt.title('Resampled Train Data')

plt.show()

y_pred = clf.predict(x_res)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_res, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                  0 |                  1 |   0.952381 |                  0.5 |
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                  1 |                  1 |          1 |                    1 |

# %% [markdown]
# # Undersampling

# %%
p = .2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 10

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y



df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.savefig('db_02.png', dpi=300)
plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())


from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
x_res, y_res = rus.fit_resample(X, y)


# db on test data
x1 = x_res['x1']
x2 = x_res['x2']

clf.fit(x_res, y_res)

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_res, s=20, edgecolor='k')
plt.title('Undersampled Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_res,
                              s=20, edgecolor='k')
plt.title('Resampled Train Data')

plt.show()

y_pred = clf.predict(x_res)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_res, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                0.5 |                  1 |   0.954545 |                 0.75 |
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |                  1 |                  1 |          1 |                    1 |

# %% [markdown]
# # Smote

# %%
p = .05

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

n = 1000

from sklearn import svm
clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)

mean = [60, 60]
cov = [[30, 0], [0, 30]]  # diagonal covariance

np.random.seed(1)
import matplotlib.pyplot as plt
x1, x2 = np.random.multivariate_normal(mean, cov, n).T

df1 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df1['y']=np.ones(n)

mean = [50, 50]
cov = [[30, 0], [0, 30]]  # diagonal covariance

x1, x2 = np.random.multivariate_normal(mean, cov, n).T


df2 = pd.DataFrame(np.array([x1, x2]).T, columns=['x1','x2'])
df2['y']=np.zeros(n)

df1 = pd.concat([df1, df2], ignore_index=True)

df = pd.concat([df1, df2], ignore_index=True)

X = df.drop(['y'], axis=1)

y = df.y



df = df.drop(df.index[0:int((1-p)*n)], axis=0)

X = df.drop(['y'], axis=1)
y = df.y

x_min, x_max = X['x1'].min() - 1, X['x1'].max() + 1
y_min, y_max = X['x2'].min() - 1, X['x2'].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))


plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Balanced Data')

plt.savefig('bal_data2.png', dpi=300)
plt.show()


clf = svm.SVC(kernel='rbf', gamma=0.01, C=1)
clf.fit(X, y)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['x1'], X['x2'], c=y,
                              s=20, edgecolor='k')
plt.title('Decision Boundary')

plt.show()

y_pred = clf.predict(X)
[tn, fp, fn, tp] = metrics.confusion_matrix(y, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())


from imblearn.over_sampling import SMOTE 
sm = SMOTE()
x_res, y_res = sm.fit_resample(X, y)


# db on test data
x1 = x_res['x1']
x2 = x_res['x2']

clf.fit(x_res, y_res)

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.scatter(x1, x2, c=y_res, s=20, edgecolor='k')
plt.title('SMOTE Data')

plt.show()

plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(x1, x2, c=y_res,
                              s=20, edgecolor='k')
plt.title('SMOTE Data')

plt.show()

y_pred = clf.predict(x_res)
[tn, fp, fn, tp] = metrics.confusion_matrix(y_res, y_pred).ravel()
    
d = pd.DataFrame({
                    'Yellow Accuracy ':[tp/(tp+fn)],
                     'Purple Accuracy ':[tn/(tn+fp)],
                      'Accuracy':[(tp+tn)/(tp+tn+fp+fn)],
                  'Balanced Accuracy ':[.5*(tp/(tp+fn) + tn/(tn+fp))]})  
print(d.to_markdown())
# Out:
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |               0.28 |              0.999 |   0.981463 |               0.6395 |
# |    |   Yellow Accuracy  |   Purple Accuracy  |   Accuracy |   Balanced Accuracy  |
# |---:|-------------------:|-------------------:|-----------:|---------------------:|
# |  0 |             0.9765 |              0.864 |    0.92025 |              0.92025 |
